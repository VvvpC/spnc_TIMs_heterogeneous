# %% [markdown]
# 这个文件调查了在0/1均一化下的beta50_theta0.2帕累托前沿的TIMs和任务表现的关系

# %% [markdown]
# 原文件名：test_beta50_01.ipynb

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import ast

# %%
# 提取数据
# MC和CQ数据
filename_path1 = r"C:\Users\Chen\Desktop\Repository\spnc_taskindependent_metrics\saved_studies\CQ_MC_Pareto_beta50_01_20251009_104203_pareto.csv"
# 任务表现数据和潜在的th01数据
filename_path2 = r"C:\Users\Chen\Desktop\Repository\spnc_taskindependent_metrics\ParetoFront_CQandMC\CQ_MC_Pareto_beta50_01_20251009_104203_pareto.csv"

def collect_data(filename_path):
    # 读取pareto文件
    data = pd.read_csv(filename_path)
    return data  # 需要返回数据，否则默认返回None

data1 = collect_data(filename_path1)
data2 = collect_data(filename_path2)

MC = data1["values"].apply(lambda x: ast.literal_eval(x)[1])
CQ = data1["values"].apply(lambda x: ast.literal_eval(x)[0])

nrmse = data2["narma10_nrmse"]
error_rate = (1-data2["ti46_accuracy"])*100
trials = data2['trial_number']

CQ_th01 = data2['kr_threshold']-data2['gr_threshold']

# %%
plt.figure(figsize=(5, 4))
plt.scatter(CQ, MC, c=MC, cmap='viridis', s=100)
cbar = plt.colorbar(label='Relative Location', ticks=[])
cbar.set_label('Relative Location', fontsize=14)
plt.xlabel('Computational Quality', fontsize=14)
plt.ylabel('Memory Capacity', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(14, 5))
# 子图1: NRMSE
sc1 = axs[0].scatter(CQ, MC, c=nrmse, cmap='viridis', s=300)
cbar1 = plt.colorbar(sc1, ax=axs[0])
cbar1.set_label('NRMSE', fontsize=14)
axs[0].set_xlabel('Computational Quality', fontsize=14)
axs[0].set_ylabel('Memory Capacity', fontsize=14)
axs[0].tick_params(axis='both', labelsize=14)
# # 标注trials
# for x, y, trial in zip(CQ_without, MC, trials):
#     axs[0].text(x, y, str(trial), fontsize=6, ha='center', va='center', color='white', fontweight='bold')
# axs[0].set_title('NRMSE', fontsize=15)

# 子图2: Error Rate
sc2 = axs[1].scatter(CQ, MC, c=error_rate, cmap='viridis', s=300)
cbar2 = plt.colorbar(sc2, ax=axs[1])
cbar2.set_label('Error Rate(%)', fontsize=14)
axs[1].set_xlabel('Computational Quality', fontsize=14)
axs[1].set_ylabel('Memory Capacity', fontsize=14)
axs[1].tick_params(axis='both', labelsize=14)
# # 标注trials
# for x, y, trial in zip(CQ_without, MC, trials):
#     axs[1].text(x, y, str(trial), fontsize=6, ha='center', va='center', color='white', fontweight='bold')
# axs[1].set_title('Error Rate(%)', fontsize=15)

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(14, 5))
# 子图1: NRMSE
sc1 = axs[0].scatter(CQ_th01, MC, c=nrmse, cmap='viridis', s=300)
cbar1 = plt.colorbar(sc1, ax=axs[0])
cbar1.set_label('NRMSE', fontsize=14)
axs[0].set_xlabel('Computational Quality', fontsize=14)
axs[0].set_ylabel('Memory Capacity', fontsize=14)
axs[0].tick_params(axis='both', labelsize=14)
# # 标注trials
# for x, y, trial in zip(CQ_without, MC, trials):
#     axs[0].text(x, y, str(trial), fontsize=6, ha='center', va='center', color='white', fontweight='bold')
# axs[0].set_title('NRMSE', fontsize=15)

# 子图2: Error Rate
sc2 = axs[1].scatter(CQ_th01, MC, c=error_rate, cmap='viridis', s=300)
cbar2 = plt.colorbar(sc2, ax=axs[1])
cbar2.set_label('Error Rate(%)', fontsize=14)
axs[1].set_xlabel('Computational Quality', fontsize=14)
axs[1].set_ylabel('Memory Capacity', fontsize=14)
axs[1].tick_params(axis='both', labelsize=14)
# # 标注trials
# for x, y, trial in zip(CQ_without, MC, trials):
#     axs[1].text(x, y, str(trial), fontsize=6, ha='center', va='center', color='white', fontweight='bold')
# axs[1].set_title('Error Rate(%)', fontsize=15)

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(14, 5))

# MC vs Error Rate （颜色随 MC 变化）
sc1 = axs[0].scatter(
    MC, nrmse,
    c=MC, cmap='viridis',s=100
)

axs[0].set_xlabel("MC", fontsize=14)
axs[0].set_ylabel("NRMSE", fontsize=14)
axs[0].tick_params(axis='both', labelsize=14)
axs[0].set_title("MC vs NRMSE", fontsize=15)
# fig.colorbar(sc1, ax=axs[0], label="MC")


# CQ vs Error Rate （颜色同样按 MC 变化）
sc2 = axs[1].scatter(
    CQ, nrmse,
    c=MC, cmap='viridis',s=100
)
axs[1].set_xlabel("CQ", fontsize=14)
axs[1].set_ylabel("NRMSE", fontsize=14)
axs[1].tick_params(axis='both', labelsize=14)
axs[1].set_title("CQ vs NRMSE", fontsize=15)
# fig.colorbar(sc2, ax=axs[1], label="MC")

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(14, 5))

# MC vs Error Rate （颜色随 MC 变化）
sc1 = axs[0].scatter(
    MC, error_rate,
    c=MC, cmap='viridis',s=100
)

axs[0].set_xlabel("MC", fontsize=14)
axs[0].set_ylabel("Error Rate(%)", fontsize=14)
axs[0].tick_params(axis='both', labelsize=14)
axs[0].set_title("MC vs Error Rate(%)", fontsize=15)
# fig.colorbar(sc1, ax=axs[0], label="MC")


# CQ vs Error Rate （颜色同样按 MC 变化）
sc2 = axs[1].scatter(
    CQ, error_rate,
    c=MC, cmap='viridis',s=100
)
axs[1].set_xlabel("CQ", fontsize=14)
axs[1].set_ylabel("Error Rate(%)", fontsize=14)
axs[1].tick_params(axis='both', labelsize=14)
axs[1].set_title("CQ vs Error Rate(%)", fontsize=15)
# fig.colorbar(sc2, ax=axs[1], label="MC")

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(14, 5))

# MC vs Error Rate （颜色随 MC 变化）
sc1 = axs[0].scatter(
    MC, error_rate,
    c=MC, cmap='viridis',s=100
)

axs[0].set_xlabel("MC", fontsize=14)
axs[0].set_ylabel("Error Rate(%)", fontsize=14)
axs[0].tick_params(axis='both', labelsize=14)
axs[0].set_title("MC vs Error Rate(%)", fontsize=15)
# fig.colorbar(sc1, ax=axs[0], label="MC")


# CQ vs Error Rate （颜色同样按 MC 变化）
sc2 = axs[1].scatter(
    CQ_th01, error_rate,
    c=MC, cmap='viridis',s=100
)
axs[1].set_xlabel("CQ", fontsize=14)
axs[1].set_ylabel("Error Rate(%)", fontsize=14)
axs[1].tick_params(axis='both', labelsize=14)
axs[1].set_title("CQ vs Error Rate(%)", fontsize=15)
# fig.colorbar(sc2, ax=axs[1], label="MC")

plt.tight_layout()
plt.show()

# %%
# 计算pearson相关系数
corr_MCnrmse = nrmse.corr(MC, method='pearson')
print(f"pearson相关系数为: {corr_MCnrmse:.2f}")

corr_MCerrorrate = error_rate.corr(MC, method='pearson')
print(f"pearson相关系数为: {corr_MCerrorrate:.2f}")

corr_CQnrmse = nrmse.corr(CQ, method='pearson')
print(f"pearson相关系数为: {corr_CQnrmse:.2f}")

corr_CQerrorrate = error_rate.corr(CQ, method='pearson')
print(f"pearson相关系数为: {corr_CQerrorrate:.2f}")
# Out:
# pearson相关系数为: 0.12
# pearson相关系数为: -0.73
# pearson相关系数为: -0.02
# pearson相关系数为: 0.84

# %% [markdown]
# 让我们看看另一个pareto front‘beta50_theta02_max_th0001’

# %%
# 提取数据
# MC和CQ数据
filename_path1 = r"C:\Users\Chen\Desktop\Repository\spnc_taskindependent_metrics\saved_studies\CQ_MC_Pareto_beta50_theta02_maxth0001_20251011_231442_pareto.csv"
# 任务表现数据和潜在的th01数据
filename_path2 = r"C:\Users\Chen\Desktop\Repository\spnc_taskindependent_metrics\ParetoFront_CQandMC\CQ_MC_Pareto_beta50_theta02_maxth0001_20251011_231442_pareto.csv"

def collect_data(filename_path):
    # 读取pareto文件
    data = pd.read_csv(filename_path)
    return data  # 需要返回数据，否则默认返回None

data1 = collect_data(filename_path1)
data2 = collect_data(filename_path2)

MC = data1["values"].apply(lambda x: ast.literal_eval(x)[1])
CQ = data1["values"].apply(lambda x: ast.literal_eval(x)[0])

nrmse = data2["narma10_nrmse"]
error_rate = (1-data2["ti46_accuracy"])*100
trials = data2['trial_number']

CQ_th01 = data2['kr_threshold']-data2['gr_threshold']

# %%
plt.figure(figsize=(5, 4))
plt.scatter(CQ, MC, c=MC, cmap='viridis', s=100)
cbar = plt.colorbar(label='Relative Location', ticks=[])
cbar.set_label('Relative Location', fontsize=14)
plt.xlabel('Computational Quality', fontsize=14)
plt.ylabel('Memory Capacity', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(14, 5))
# 子图1: NRMSE
sc1 = axs[0].scatter(CQ, MC, c=nrmse, cmap='viridis', s=300)
cbar1 = plt.colorbar(sc1, ax=axs[0])
cbar1.set_label('NRMSE', fontsize=14)
axs[0].set_xlabel('Computational Quality', fontsize=14)
axs[0].set_ylabel('Memory Capacity', fontsize=14)
axs[0].tick_params(axis='both', labelsize=14)
# # 标注trials
# for x, y, trial in zip(CQ_without, MC, trials):
#     axs[0].text(x, y, str(trial), fontsize=6, ha='center', va='center', color='white', fontweight='bold')
# axs[0].set_title('NRMSE', fontsize=15)

# 子图2: Error Rate
sc2 = axs[1].scatter(CQ, MC, c=error_rate, cmap='viridis', s=300)
cbar2 = plt.colorbar(sc2, ax=axs[1])
cbar2.set_label('Error Rate(%)', fontsize=14)
axs[1].set_xlabel('Computational Quality', fontsize=14)
axs[1].set_ylabel('Memory Capacity', fontsize=14)
axs[1].tick_params(axis='both', labelsize=14)
# # 标注trials
# for x, y, trial in zip(CQ_without, MC, trials):
#     axs[1].text(x, y, str(trial), fontsize=6, ha='center', va='center', color='white', fontweight='bold')
# axs[1].set_title('Error Rate(%)', fontsize=15)

plt.tight_layout()
plt.show()

# %% [markdown]
# 再看看另一个pareto front‘beta50_max_th0001’

# %%
# 提取数据
# MC和CQ数据
filename_path1 = r"C:\Users\Chen\Desktop\Repository\spnc_taskindependent_metrics\saved_studies\CQ_MC_Pareto_beta50_th0001_20251011_230957_pareto.csv"
# 任务表现数据和潜在的th01数据
filename_path2 = r"C:\Users\Chen\Desktop\Repository\spnc_taskindependent_metrics\ParetoFront_CQandMC\CQ_MC_Pareto_beta50_th0001_20251011_230957_pareto.csv"

def collect_data(filename_path):
    # 读取pareto文件
    data = pd.read_csv(filename_path)
    return data  # 需要返回数据，否则默认返回None

data1 = collect_data(filename_path1)
data2 = collect_data(filename_path2)

MC = data1["values"].apply(lambda x: ast.literal_eval(x)[1])
CQ = data1["values"].apply(lambda x: ast.literal_eval(x)[0])

nrmse = data2["narma10_nrmse"]
error_rate = (1-data2["ti46_accuracy"])*100
trials = data2['trial_number']

CQ_th01 = data2['kr_threshold']-data2['gr_threshold']

# %%
plt.figure(figsize=(5, 4))
plt.scatter(CQ, MC, c=MC, cmap='viridis', s=100)
cbar = plt.colorbar(label='Relative Location', ticks=[])
cbar.set_label('Relative Location', fontsize=14)
plt.xlabel('Computational Quality', fontsize=14)
plt.ylabel('Memory Capacity', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(14, 5))
# 子图1: NRMSE
sc1 = axs[0].scatter(CQ, MC, c=nrmse, cmap='viridis', s=300)
cbar1 = plt.colorbar(sc1, ax=axs[0])
cbar1.set_label('NRMSE', fontsize=14)
axs[0].set_xlabel('Computational Quality', fontsize=14)
axs[0].set_ylabel('Memory Capacity', fontsize=14)
axs[0].tick_params(axis='both', labelsize=14)
# # 标注trials
# for x, y, trial in zip(CQ_without, MC, trials):
#     axs[0].text(x, y, str(trial), fontsize=6, ha='center', va='center', color='white', fontweight='bold')
# axs[0].set_title('NRMSE', fontsize=15)

# 子图2: Error Rate
sc2 = axs[1].scatter(CQ, MC, c=error_rate, cmap='viridis', s=300)
cbar2 = plt.colorbar(sc2, ax=axs[1])
cbar2.set_label('Error Rate(%)', fontsize=14)
axs[1].set_xlabel('Computational Quality', fontsize=14)
axs[1].set_ylabel('Memory Capacity', fontsize=14)
axs[1].tick_params(axis='both', labelsize=14)
# # 标注trials
# for x, y, trial in zip(CQ_without, MC, trials):
#     axs[1].text(x, y, str(trial), fontsize=6, ha='center', va='center', color='white', fontweight='bold')
# axs[1].set_title('Error Rate(%)', fontsize=15)

plt.tight_layout()
plt.show()
